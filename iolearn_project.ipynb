# %% [markdown]
# <a href="https://colab.research.google.com/github/arman2000/Machine-Learning-Python/blob/master/iolearn_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2 as cv

# %%
image = cv.imread("image.png")
image = np.array(image)
print(image.dtype)
# Out:
# uint8

# %%
plt.imshow(image)

# %%
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))

# %%
model = cv.CascadeClassifier("model.xml")

# %%
face = model.detectMultiScale(image)

# %%
print(face)
# Out:
# [[154 170  76  76]]

# %%
image.shape
# Out:
# (459, 412, 3)

# %%
x = face[0][0]
y = face[0][1]
a = face[0][2]
b = face[0][3]

# %%
image = cv.rectangle(image , (x,y),(x+a, y+b) , (0,255,0), 3)

# %%
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
plt.imshow(image)
